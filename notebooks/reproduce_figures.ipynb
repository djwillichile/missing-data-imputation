# %% [markdown]
# # Notebook para Reproducir las Figuras de la Guía de Imputación
#
# Este notebook permite ejecutar el código Python necesario para generar todas las figuras y datos de la guía sobre datos faltantes y métodos de imputación.

# %% [markdown]
# ## 1. Instalar Dependencias
#
# Primero, nos aseguramos de que todas las librerías necesarias estén instaladas.

# %%
# !pip install numpy pandas matplotlib scikit-learn

# %% [markdown]
# ## 2. Generar Histogramas de Imputación por Media
#
# Este bloque de código ejecuta `generate_histograms.py` para crear las figuras `imputation_comparison.png` y `variance_comparison.png`.

# %%
import sys
import os

# Añadir la carpeta de código al path para importar los scripts
sys.path.append(os.path.abspath("../code"))

import generate_histograms

# %% [markdown]
# ## 3. Generar Figuras del Ejemplo de Imputación KNN
#
# Este bloque ejecuta `knn_imputation_example.py` para crear las figuras `knn_vs_mean_comparison.png` y `knn_scatter_comparison.png`, además del dataset de ejemplo `sample_dataset.csv`.

# %%
import knn_imputation_example

# %% [markdown]
# ## 4. Visualizar las Figuras Generadas
#
# Ahora, mostramos las figuras que se han guardado en la carpeta `/figures`.

# %%
from IPython.display import Image, display

FIGURES_DIR = "../figures/"

print("Figura 1: Comparación de distribuciones (Imputación por Media)")
display(Image(filename=os.path.join(FIGURES_DIR, "imputation_comparison.png")))

print("
Figura 2: Comparación de Varianza")
display(Image(filename=os.path.join(FIGURES_DIR, "variance_comparison.png")))

print("
Figura 3: Diagrama de Flujo de Imputación")
display(Image(filename=os.path.join(FIGURES_DIR, "imputation_flow.png")))

print("
Figura 4: Comparación KNN vs. Media")
display(Image(filename=os.path.join(FIGURES_DIR, "knn_vs_mean_comparison.png")))

print("
Figura 5: Diagrama de Dispersión KNN")
display(Image(filename=os.path.join(FIGURES_DIR, "knn_scatter_comparison.png")))
